# %% [markdown]
# <a href="https://colab.research.google.com/github/VagnerProjects/DataScience-Games/blob/main/DataSciencePandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install plotly --upgrade
# Out:
# ...
#      |████████████████████████████████| 20.6 MB 80 kB/s
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 4.4.1
#     Uninstalling plotly-4.4.1:
#       Successfully uninstalled plotly-4.4.1
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from collections import Counter

# %%
dataset_games = pd.read_csv('/content/sample_data/vgsales.csv')

# %%
dataset_games_analyts = dataset_games.rename(columns={'Name': 'Nome', 'Platform': 'Plataforma', 'Year':'Ano', 'Genre':'Genero',
                                                      'Publisher': 'Publicadora', 'NA_Sales': 'America_Norte', 'EU_Sales':'Europa', 'JP_Sales': 'Japao',
                                                      'Other_Sales': 'Resto_Mundo', 'Global_Sales': 'Vendas_Globais'})

dataset_games_analyts.head(30)
plt.hist(x=dataset_games_analyts['America_Norte']);

# %%
dataset_games_analyts.loc[pd.isnull(dataset_games_analyts['Ano'])]
# Out:
#         Rank                         Nome  ... Resto_Mundo  Vendas_Globais
# 179      180              Madden NFL 2004  ...        0.71            5.23
# 377      378             FIFA Soccer 2004  ...        0.51            3.49
# 431      432   LEGO Batman: The Videogame  ...        0.29            3.17
# 470      471   wwe Smackdown vs. Raw 2006  ...        0.41            3.00
# 607      608               Space Invaders  ...        0.03            2.53
# ...      ...                          ...  ...         ...             ...
# 16307  16310                Freaky Flyers  ...        0.00            0.01
# 16327  16330                    Inversion  ...        0.00            0.01
# 16366  16369  Hakuouki: Shinsengumi Kitan  ...        0.00            0.01
# 16427  16430                 Virtua Quest  ...        0.00            0.01
# 16493  16496                   The Smurfs  ...        0.00            0.01
#
# [271 rows x 11 columns]

# %%
dataset_games_analyts['Ano'].fillna(dataset_games_analyts['Ano'].mean(), inplace = True)
dataset_games_analyts.loc[pd.isnull(dataset_games_analyts['Ano'])]
# Out:
# Empty DataFrame
# Columns: [Rank, Nome, Plataforma, Ano, Genero, Publicadora, America_Norte, Europa, Japao, Resto_Mundo, Vendas_Globais]
# Index: []

# %%
dataset_games_analyts['Ano'].mean()
# Out:
# 2006.4064433147682

# %%
dataset_games_analyts.isnull().sum()

dataset_games_analyts.loc[pd.isnull(dataset_games_analyts['Publicadora'])]

dataset_games_analyts
# Out:
#         Rank  ... Vendas_Globais
# 0          1  ...          82.74
# 1          2  ...          40.24
# 2          3  ...          35.82
# 3          4  ...          33.00
# 4          5  ...          31.37
# ...      ...  ...            ...
# 16593  16596  ...           0.01
# 16594  16597  ...           0.01
# 16595  16598  ...           0.01
# 16596  16599  ...           0.01
# 16597  16600  ...           0.01
#
# [16598 rows x 11 columns]

# %%
len(dataset_games_analyts.loc[dataset_games_analyts['Publicadora'] == 'Nintendo'])
# Out:
# 703

# %%
len(dataset_games_analyts.loc[dataset_games_analyts['Publicadora'] != 'Nintendo'])
# Out:
# 15895

# %%
len(dataset_games_analyts.loc[dataset_games_analyts['Publicadora'] == 'Activision'])
# Out:
# 975

# %%
dataset_games_analyts.describe()
# Out:
#                Rank           Ano  ...   Resto_Mundo  Vendas_Globais
# count  16598.000000  16598.000000  ...  16598.000000    16598.000000
# mean    8300.605254   2006.406443  ...      0.048063        0.537441
# std     4791.853933      5.781197  ...      0.188588        1.555028
# min        1.000000   1980.000000  ...      0.000000        0.010000
# 25%     4151.250000   2003.000000  ...      0.000000        0.060000
# 50%     8300.500000   2007.000000  ...      0.010000        0.170000
# 75%    12449.750000   2010.000000  ...      0.040000        0.470000
# max    16600.000000   2020.000000  ...     10.570000       82.740000
#
# [8 rows x 7 columns]

# %%
dataset_games_analyts_v2 = dataset_games_analyts['Publicadora']
letter_counts = Counter(dataset_games_analyts_v2)
df = pd.DataFrame.from_dict(letter_counts, orient='index')

letter_counts.most_common()
# Out:
# [('Electronic Arts', 1351),
#  ('Activision', 975),
#  ('Namco Bandai Games', 932),
#  ('Ubisoft', 921),
#  ('Konami Digital Entertainment', 832),
#  ('THQ', 715),
#  ('Nintendo', 703),
#  ('Sony Computer Entertainment', 683),
#  ('Sega', 639),
#  ('Take-Two Interactive', 413),
#  ('Capcom', 381),
#  ('Atari', 363),
#  ('Tecmo Koei', 338),
#  ('Square Enix', 233),
#  ('Warner Bros. Interactive Entertainment', 232),
#  ('Disney Interactive Studios', 218),
#  ('Unknown', 203),
#  ('Eidos Interactive', 198),
#  ('Midway Games', 198),
#  ('505 Games', 192),
#  ('Microsoft Game Studios', 189),
#  ('Acclaim Entertainment', 184),
#  ('D3Publisher', 184),
#  ('Vivendi Games', 164),
#  ('Codemasters', 152),
#  ('Idea Factory', 129),
#  ('Deep Silver', 122),
#  ('Nippon Ichi Software', 105),
#  ('Zoo Digital Publishing', 104),
#  ('Majesco Entertainment', 92),
#  ('LucasArts', 90),
#  ('Rising Star Games', 86),
#  ('Hudson Soft', 81),
#  ('Banpresto', 73),
#  ('Bethesda Softworks', 71),
# ...

# %%
dataset_games_analyts['Publicadora'].fillna('Electronic Arts', inplace=True)

# %%
dataset_games_analyts
# Out:
#         Rank  ... Vendas_Globais
# 0          1  ...          82.74
# 1          2  ...          40.24
# 2          3  ...          35.82
# 3          4  ...          33.00
# 4          5  ...          31.37
# ...      ...  ...            ...
# 16593  16596  ...           0.01
# 16594  16597  ...           0.01
# 16595  16598  ...           0.01
# 16596  16599  ...           0.01
# 16597  16600  ...           0.01
#
# [16598 rows x 11 columns]
